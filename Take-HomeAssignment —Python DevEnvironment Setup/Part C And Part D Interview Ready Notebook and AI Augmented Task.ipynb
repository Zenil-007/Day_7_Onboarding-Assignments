# %% [markdown]
# Q1: Conceptual — Explain virtual environments
# In 3-4 sentences, explain to a non-technical interviewer: What is a Python virtual environment? Why do
# developers use them? What happens if you don't use one? Give a real-world analogy

# %% [markdown]
# Its actually an eviourement that developer's create to prevent version conflict, for example i have created an application where a person needs opencv 3.2 verion because it contains grey scale imagining and in the same computer i need to create an application where i need opencv 2.4. What i would do is rather than overwriting for each run i would just create a different virtual enviourements for both and in that way it would be benificial to me and help me keep my stuff organized

# %% [markdown]
# # This code has 5 issues. Find and fix ALL of them.
# # Then make it pass Pylint with score >= 8/10.
# import os, sys, json
# def checkVersion():
# v = sys.version_info
# if v.major >= 3 and v.minor>=11:
# return "Good"
# else:
# return "Bad"
# result = checkVersion()
# temp = 42
# print( "Version status:" , result )
#
# The 5 Issues Identified
# Multiple Imports on One Line: import os, sys, json violates PEP 8. Imports should be on separate lines.
#
# Unused Imports: os and json are imported but never used, which clutches up the namespace.
#
# Naming Convention (CamelCase): checkVersion uses camelCase. Python functions should use snake_case (e.g., check_version).
#
# Inconsistent Whitespace: There is missing whitespace around operators (e.g., v.minor>=11) and unnecessary spaces inside the print function.
#
# Global Scope Logic: The logic (variable assignments and printing) is sitting in the global scope. For better structure and Pylint scores, it should be protected by a if __name__ == "__main__": block.

# %%
import os, sys, json ## multiple imports are happening on one line
def checkVersion():
    v = sys.version_info
    if v.major >= 3 and v.minor>=11:
        return "Good"
    else:
        return "Bad"
    
result = checkVersion()
temp = 42
print( "Version status:" , result )
# Out:
# Version status: Good

# %% [markdown]
# A junior developer says: "I installed numpy but Python says ModuleNotFoundError: No module named 'numpy'".
# Give 3 possible causes and the diagnostic command for each.

# %% [markdown]
# There might me 3 possible causes and the diagnostic command
#
# 1. Missing Package,pip list,Is numpy in the list?
# 2. Wrong Version,python --version,Does it match the version where you ran pip?
# 3. Wrong Interpreter,sys.executable,Is this the path to your onboarding_env?
